# %% [markdown]
# ***
#
# # **COMP 4211: Machine Learning**
# # **Tutorial 2: Matplotlib & sklearn (linear regression)**
# ## TA: Donald (wlchanan@cse.ust.hk)
#
# ***

# %% [markdown]
# # **Objectives**
# 1. To understand how to import and to use matplotlib.
# 2. To understand how to draw several types of plots in different format.
# 3. To understand how to perform linear regression with sklearn.

# %% [markdown]
# # **Matplotlib**
#
#
# matplotlib is used to draw plots, charts, and graphs (the name matplot came from Matlab).

# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
print(matplotlib.__version__) # matplotlib version >= 3.0 is recommended
# Out:
# 3.1.3

# %%
# Simple plot
x = [1,2,3,4,5]
y = [1,2,3,4,5]

plt.scatter(x, y)

# %%
# Plotting with Python list
X = range(100) # X = [1,2,3, ..., 99]
Y = [t ** 2 for t in X] # Y = [1, 4, 9, ..., 9801]
plt.plot(X, Y)
plt.show()

# Plotting with Numpy array, they look like the same. Yes.
X = np.arange(100) # X = [1,2,3, ..., 99]
Y = [t ** 2 for t in X] # Y = [1, 4, 9, ..., 9801]
plt.plot(X, Y)
plt.show()

# %%
# Set figure style 
# Reference https://matplotlib.org/api/_as_gen/matplotlib.pyplot.figure.html
plt.figure(num=1, figsize=(15, 4), dpi=80, facecolor='red')

# Subplot: drawing mutiple plots in grid
x = [1,2,3,4,5]
y = [1,2,3,4,5]

plt.subplot(1,2,1)  # the 3 arguments means: total of 1 row, 2 cols, current plot is 1st
plt.scatter(x, y)

plt.subplot(1,2,2)  # the 3 arguments means: total of 1 row, 2 cols, current plot is 2nd
plt.plot(x, y)

plt.show()

# %%
# Figure setting in different way
from pylab import rcParams
rcParams['figure.figsize'] = 5,5 # plt.figure(figsize=(5, 5))
x = range(100)
y = [i**2 for i in x]

# Drawing dotted line
# Reference https://matplotlib.org/api/_as_gen/matplotlib.pyplot.plot.html
plt.plot(x, y, 'g--')
plt.show()

# %%
# draw sin curve
import math
X = np.linspace(0, 10, 100) # in range 0 to 10 (inclusive), divide into 100 floating point numbers
Y = [math.sin(x) for x in X]

plt.plot(X, Y)
plt.show()

# %%
X
# Out:
# array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#         0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#         1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#         1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#         2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#         2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#         3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#         3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#         4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#         4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#         5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#         5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#         6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
# ...

# %%
# draw both sin and cos curve
# Drawing multiple charts in a canvas.
X = np.linspace(0, 10, 100) # in range 0 to 10 (inclusive), divide into 100 floating point numbers
Ysin = [math.sin(x) for x in X]
Ycos = [math.cos(x) for x in X]

plt.plot(X, Ysin)
plt.plot(X, Ycos)
plt.show()

# %%
# Asterisk (*) for unpacking list
# Reference https://medium.com/understand-the-python/understanding-the-asterisk-of-python-8b9daaa4a558
a = [1,2,3,4,5]
b = ['a','b','c','d','e']
c = zip(a, b)
d, e, f, g, h = zip(a, b)


print(c)
print(*c)
print(d)
print(e)
# Out:
# ...
# (1, 'a') (2, 'b') (3, 'c') (4, 'd') (5, 'e')
# (1, 'a')
# (2, 'b')

# %%
# Using zip in Python
data = [[0, 0],
    [1, 1],
    [2, 4],
    [4, 16],
    [5, 25],
    [6, 36]]
print('data', data)
print('*data', *data)


X, Y = zip(*data) # same as zip([0, 0], [1, 1], [2, 4], [4, 16], [5, 25], [6, 36])
print('X', X)
print('Y', Y)
print('zip', zip(*data))

plt.plot(X, Y)
plt.show()
# Out:
# data [[0, 0], [1, 1], [2, 4], [4, 16], [5, 25], [6, 36]]
# *data [0, 0] [1, 1] [2, 4] [4, 16] [5, 25] [6, 36]
# X (0, 1, 2, 4, 5, 6)
# Y (0, 1, 4, 16, 25, 36)
# zip <zip object at 0x10c339808>

# %%
plt.figure(num=1, figsize=(15, 4), dpi=80)

# Drawing bar chart
data = [5., 25., 50., 20.]

plt.subplot(1,2,1)
plt.bar(range(len(data)), data)

plt.subplot(1,2,2)
plt.barh(range(len(data)), data)
plt.show()
# Out:
# [ 5. 10. 15. 20.]

# %%
# Use figure number and save the figure
x = np.arange(100)

plt.figure()
plt.plot(x)

plt.savefig('figure.png')

# %%
# Drawing multiple bar charts
data = [[5., 25., 50., 20.,],
       [4., 23., 51., 17.],
       [6., 22., 52., 19.]]

plt.bar(range(4), data[0], width=0.25, color='yellow')
plt.bar([x + 0.25 for x in range(4)], data[1], width = 0.25, color='green')
plt.bar([x + 0.50 for x in range(4)], data[2], width = 0.25, color='orange')

plt.show()

# %%
# Using Python function and numpy

def plt_slope(X, Y):
  Xs = X[1:] - X[:-1]
  Ys = Y[1:] - Y[:-1]
  plt.plot(X[1:], Ys / Xs)
  
X = np.linspace(-3, 3, 100) # in range -3 to 3 (inclusive), divide into 100 floating point numbers evenly
Y = np.exp(-(X**2)) # X to the power of 2
y = np.exp(X)

plt.figure(figsize=(15, 4), dpi=80)

plt.subplot(1,2,1)
plt.plot(X, Y)
plt_slope(X, Y)
  
plt.subplot(1,2,2)
plt.plot(X, y)
plt_slope(X, y)

plt.show()

# %% [markdown]
# ### Subplot, marker, color

# %% [markdown]
# $z = \sqrt{x^2+y^2}$

# %%
# Fixing random state for reproducibility
np.random.seed(100)

x = np.random.rand(10)
y = np.random.rand(10)
z = np.sqrt(x**2 + y**2)
#np.set_printoptions(precision = 2, threshold=30)
print('x : ', x)
print('y : ', y)
print('z : ', z)

plt.subplot(321)
plt.scatter(x, y, s=80, c=z, marker=">")

plt.subplot(322)
plt.scatter(x, y, s=80, c=z, marker=(5, 0))

verts = np.array([[-1, -1], [1, -1], [1, 1], [-1, -1]])
plt.subplot(323)
plt.scatter(x, y, s=80, c=z, marker=verts)

plt.subplot(324)
plt.scatter(x, y, s=80, c=z, marker=(5, 1))

plt.subplot(325)
plt.scatter(x, y, s=80, c=z, marker='+')

plt.subplot(326)
plt.scatter(x, y, s=80, c=z, marker=(5, 2))

plt.show()
# Out:
# x :  [0.54 0.28 0.42 0.84 0.   0.12 0.67 0.83 0.14 0.58]
# y :  [0.89 0.21 0.19 0.11 0.22 0.98 0.81 0.17 0.82 0.27]
# z :  [1.04 0.35 0.46 0.85 0.22 0.99 1.05 0.84 0.83 0.64]

# %%
# Show multiple subplots with different yscales
# reference https://matplotlib.org/api/_as_gen/matplotlib.pyplot.yscale.html

# Fixing random state for reproducibility
np.random.seed(10)

# make up some data in the interval [0, 1]
y = np.random.normal(loc=0.5, scale=0.4, size=1000)
y = y[(y > 0) & (y < 1)] # truncate to 0<y<1
y.sort()
x = np.arange(len(y))
np.set_printoptions(precision = 2, threshold=10)
print('x:',x)
print('y:',y)
print('len(x):',len(x), ', len(y):',len(y))

plt.figure(figsize=(15,8))

# linear
plt.subplot(221)
plt.plot(x, y)
plt.yscale('linear')
plt.title('linear')
plt.grid(True)

# log
plt.subplot(222)
plt.plot(x, y)
plt.yscale('log')
plt.title('log')
plt.grid(True)

# logit
plt.subplot(223)
plt.plot(x, y)
plt.yscale('logit')
plt.title('logit')
plt.grid(True)

# Format the minor tick labels of the y-axis into empty strings with
# `NullFormatter`, to avoid cumbering the axis with too many labels.
from matplotlib.ticker import NullFormatter  # useful for `logit` scale
plt.gca().yaxis.set_minor_formatter(NullFormatter())

plt.show()
# Out:
# x: [  0   1   2 ... 820 821 822]
# y: [0.   0.   0.   ... 0.99 0.99 1.  ]
# len(x): 823 , len(y): 823

# %% [markdown]
# # Introduction to Linear Regression

# %% [markdown]
# Linear regression is a good starting point for modeling tasks because it can be fit very quickly, and are very interpretable. You have been taught the simple form of a linear regression model from the course. In this section we will start with a quick intuitive walk-through of the mathematics behind this well-known problem to see how linear models can be generalized to account for more complicated shapes of data.

# %%
# Import libraries
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Simple Linear Regression
#
# We will start with the most familiar linear regression, a straight-line fit to data.
# A straight-line fit is a model of the form
# $$
# y = ax + b
# $$
# where $a$ is *coefficient*, and $b$ is *bias*.
#
# Consider the following data, which is scattered about a line with a slope of 2 and an intercept of -5:

# %%
# Randomly generate data points
rng = np.random.RandomState(10)
x = 10 * rng.rand(50)
y = 2 * x - 5 + rng.randn(50)
print(x)
print(y)
plt.scatter(x, y)
plt.show()
# Out:
# [7.71 0.21 6.34 ... 8.84 3.26 1.65]
# [ 9.62 -4.8   7.33 ... 12.92  1.45 -2.45]

# %% [markdown]
# We can use Scikit-Learn's ``LinearRegression`` estimator to fit this data and construct the best-fit line (regression line):

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

model.fit(x[:, np.newaxis], y) # x[:, np.newaxis] == x.reshape(-1, 1)

xfit = np.linspace(0, 10, 1000)
yfit = model.predict(xfit[:, np.newaxis])

plt.scatter(x, y)
plt.plot(xfit, yfit)
plt.show()
# Out:
# [[7.71]
#  [0.21]
#  [6.34]
#  ...
#  [8.84]
#  [3.26]
#  [1.65]]
# [[7.71]
#  [0.21]
#  [6.34]
#  ...
#  [8.84]
#  [3.26]
#  [1.65]]
# [7.71 0.21 6.34 ... 8.84 3.26 1.65]

# %% [markdown]
# The slope and intercept of the data are contained in the model's fit parameters, which in Scikit-Learn are always marked by a trailing underscore.
# Here the relevant parameters are ``coef_`` and ``intercept_``:

# %%
print("Model slope:    ", model.coef_[0])
print("Model intercept:", model.intercept_)
# Out:
# Model slope:     1.9715192959453205
# Model intercept: -4.815463276083515

# %% [markdown]
# We see that the results are very close to the inputs, as we might hope.

# %% [markdown]
# The ``LinearRegression`` estimator is much more capable than this, however—in addition to simple straight-line fits, it can also handle multidimensional linear models of the form
# $$
# y = a_0 + a_1 x_1 + a_2 x_2 + \cdots
# $$
# where there are multiple $x$ values.
# Geometrically, this is similar to fitting a plane to points in three dimensions, or fitting a hyper-plane to points in higher dimensions. The multidimensional nature of such regressions makes them more difficult to visualize, but we can see one of these fits in action by building some example data, using NumPy's matrix multiplication operator:
#
# Reference https://scikit-learn.org/stable/auto_examples/linear_model/plot_ols.html#sphx-glr-auto-examples-linear-model-plot-ols-py

# %%
# Fit the model to the data points
rng = np.random.RandomState(1)
X = 10 * rng.rand(100, 3)
y = 0.5 + np.dot(X, [1.5, -2., 1.])

model.fit(X, y)
print(model.intercept_)
print(model.coef_)
# Out:
# 0.50000000000001
# [ 1.5 -2.   1. ]

# %%
# 1. load data set.
# 2. split the data set into x (feature) and y (label).
# 3. split the data set into train and test.
# 4. create model
# 5. fit the model into data set.
# 6. predict the output of the model.
# 7. evaluate the performance.
# 8. visualize the results.

import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score

# Load the diabetes dataset
diabetes = datasets.load_diabetes()

# Use only one feature
diabetes_X = diabetes.data[:, np.newaxis, 2]

# Split the data into training/testing sets
diabetes_X_train = diabetes_X[:-20]
diabetes_X_test = diabetes_X[-20:]

# Split the targets into training/testing sets
diabetes_y_train = diabetes.target[:-20]
diabetes_y_test = diabetes.target[-20:]

# Create linear regression object
regr = linear_model.LinearRegression()

# Train the model using the training sets
regr.fit(diabetes_X_train, diabetes_y_train)

# Make predictions using the testing set
diabetes_y_pred = regr.predict(diabetes_X_test)

# The coefficients
print('Coefficients: \n', regr.coef_)
# The mean squared error
print("Mean squared error: %.2f"
      % mean_squared_error(diabetes_y_test, diabetes_y_pred))
# Explained variance score: 1 is perfect prediction
print('Variance score: %.2f' % r2_score(diabetes_y_test, diabetes_y_pred))

# Plot outputs
plt.scatter(diabetes_X_test, diabetes_y_test,  color='black')
plt.plot(diabetes_X_test, diabetes_y_pred, color='blue', linewidth=3)

plt.xticks(())
plt.yticks(())

plt.show()
# Out:
# Coefficients:
#  [938.24]
# Mean squared error: 2548.07
# Variance score: 0.47

# %% [markdown]
# Means squared error: $\text{MSE} (y, \hat{y}) = \frac{1}{n}\sum^n_{i=1}(y_i-\hat{y})^2$
#
# $R^2$ score (Variance score): $R^2(y, \hat{y}) = 1-\frac{\sum^n_{i=1}(y_i-\hat{y})^2}{\sum^n_{i=1}(y_i-\bar{y})^2}$
